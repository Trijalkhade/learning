# %%
# Name : Trijal Khade PRN: 124B1B187 Batch: L2
# Program to convert celsius to fahrenheit

# %%
print("Enter celsius:")
celsius = float(input())
fahrenheit = (celsius * 9/5) + 32
print('Fahrenheit =',fahrenheit)
# Out:
# Enter celsius:
# 100
# Fahrenheit = 212.0
