# %%
print("Enter the number:")
n=int(input())
if n%2 == 0:
  print("{} is Even".format(n))
else:
  print("{} is Odd".format(n))
# Out:
# Enter the number:
# 5
# 5 is Odd

# %%
text = "Fun for ME"
print("Converted string swapcase:")
print(text.swapcase())
print("\nConverted string lower:")
print(text.lower())
print("\nConverted string upper:")
print(text.upper())
print("\nConverted string title:")
print(text.title())
print("\nConverted string capitalize:")
print(text.capitalize())
# Out:
# Converted string swapcase:
# fUN FOR me
#
# Converted string lower:
# fun for me
#
# Converted string upper:
# FUN FOR ME
#
# Converted string title:
# Fun For Me
#
# Converted string capitalize:
# Fun for me

# %%
message = "Pyhton is fun programming language"
print(message.find('fun'))
# Out:
# 10

# %%
text = "Python is easy to learn."
result = text.index('is')
print(result)
# Out:
# 7

# %%
#symbol = "012345“
symbol = "012345"
print(symbol.isnumeric())
text = "Python3"
print(text.isnumeric())
# Out:
# True
# False

# %%
message = 'Python is fun'

print(message.startswith('Python'))
# Out:
# True

# %%
string = "Python is fun"
print(string.partition('is '))
# Out:
# ('Python ', 'is ', 'fun')

# %%
str = input()
str = str[-2:] + str[:-2]
print(str)
# Out:
# trijal
# altrij

# %%
# Check to find palindrome
string = input()
if string == string[::-1]:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# madam
# Palindrome

# %%
# Removing of consecutive duplicate
str = input()
str1 = ""
for i in range(len(str)-1):
  if (str[i] != str[i+1]):
    str1+=str[i]
  else:
    str1+=str[i]

print(str1)
# Out:
# trijall
# trijal

# %%
# Removing of all duplicate
str = input()
for i in range(len(str)-1):
  for j in range(i+1,len(str)):
    if str[i] == str[j]:
      str = str[j] + str.replace(str[j],"")
      break
print(str)
# Out:
# trijalla
# latrij
